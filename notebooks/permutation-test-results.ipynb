# %% [markdown]
# ## Permutation test results

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from tqdm import tqdm

# %%
def load_interaction(project_name:str) -> pd.DataFrame:

    use_columns = ["interaction", 'rmst_diff_f1+f2', 'rmst_diff_f1-f2', 'rmst_diff_f1*f2']

    interactions = pd.read_csv(f"../computed_interactions/{project_name}.csv", index_col=[0], usecols=use_columns)
    interactions = interactions.fillna(-1)
    return interactions

def load_permutations(project_name:str) -> list:
    
    use_columns = ["interaction", 'rmst_diff_f1+f2', 'rmst_diff_f1-f2', 'rmst_diff_f1*f2']

    permutations = [
        pd.read_csv(f"../computed_permutations/{project_name}/{fn}", index_col=[0], usecols=use_columns)
        for fn in tqdm(os.listdir(f"../computed_permutations/{project_name}/"))
    ]
    return permutations

def get_interaction_values(df, interaction_column, N_INTERACTIONS, placeholder=-1):
    values = df[interaction_column].dropna().values
    return np.append(values, [placeholder]*(N_INTERACTIONS - len(values)))

# %%
GENES = pd.read_csv("../data/L1000.txt", header=None)
N_GENES = len(GENES)
N_INTERACTIONS = int((N_GENES * (N_GENES-1))/2)
interaction_types = ['rmst_diff_f1+f2', 'rmst_diff_f1-f2', 'rmst_diff_f1*f2']
interaction_label = {
    'rmst_diff_f1+f2': "additive",
    'rmst_diff_f1-f2': "competing",
    'rmst_diff_f1*f2': "xor"
}

# %%
project_names = os.listdir("../computed_permutations/")
PLACEHOLDER = -1
SIGNIFICANCE_THRESHOLD = 99.99
print(project_names)
# Out:
# ['METABRIC', 'KIRC', 'HNSC']

# %%
with open("../data/permutation_test_results.csv", "a") as f:
    f.write("project;interaction-type;n-hits;hits\n")

for project_name in project_names:
    print(project_name)

    project_interactions = load_interaction(project_name)
    project_permutations = load_permutations(project_name)

    for interaction in interaction_types:
        
        permutation_values = np.concatenate([
            get_interaction_values(project_permutations[i], interaction, N_INTERACTIONS, PLACEHOLDER)
            for i in range(len(project_permutations))
        ])

        permutation_threshold = np.percentile(permutation_values, SIGNIFICANCE_THRESHOLD)
        del permutation_values

        hits = project_interactions.index[project_interactions[interaction] > permutation_threshold].values

        with open("../data/permutation_test_results.csv", "a") as f:
            f.write(f"{project_name};{interaction_label[interaction]};{len(hits)};[{','.join(x for x in hits)}]\n")
# Out:
# HNSC
# 100%|██████████| 100/100 [01:06<00:00,  1.50it/s]
# ['ABHD6*BAG6' 'ABHD6*MTF2' 'AKR1A1*FOS' 'AKR1A1*PYCR1' 'AKT1*BNIP3'
#  'AKT1*CCDC85B' 'ALDOA*ANO10' 'ALDOC*PSME1' 'AMDHD2*UBE2J1' 'ARL4C*CDK7'
#  'ATMIN*IKBKE' 'ATP11B*NT5DC2' 'ATP6V0B*CLTB' 'AXIN1*CDK1' 'BAG6*STXBP2'
#  'BDH1*ID2' 'BDH1*IKBKB' 'BDH1*NISCH' 'BNIP3*CCND3' 'BNIP3*CDC42'
#  'BNIP3*ECD' 'BNIP3*SCP2' 'BNIP3*TOMM70A' 'BRCA1*DYNLT3' 'CAPN1*HES1'
#  'CASP2*FBXL12' 'CBR1*KIAA0355' 'CCDC85B*CDC42' 'CCDC85B*CRYZ'
#  'CCDC85B*GALE' 'CCDC85B*SRC' 'CCDC85B*SYPL1' 'CCDC92*PUM2' 'CCND3*CHIC2'
#  'CCND3*NRIP1' 'CCNE2*DUSP14' 'CCT7*DRAP1' 'CCT7*GNAI1' 'CDK5R1*P4HTM'
#  'CDK6*GNPDA1' 'CDK7*CTNNAL1' 'CEP57*TJP1' 'CFLAR*ZNF131' 'CGRRF1*SFN'
#  'CHEK1*DAXX' 'CLTB*DUSP3' 'CLTB*TXNDC9' 'COG7*EIF4G1' 'COL1A1*RFC5'
#  'CSK*VPS28' 'CTSL1*MRPL18' 'CTSL1*USP14' 'CXCR4*HMGCS1' 'DCTD*DRAP1'
#  'DNAJB1*GNA11' 'DNAJB1*PUM2' 'DNAJB6*ERBB3' 'DNAJC15*DRAP1'
#  'DNAJC15*ITFG1' 'DNAJC15*KCTD5' 'DNAJC15*OXA1L' 'DNAJC15*PCBD1'
#  'DNAJC15*PGRMC1' 'DNAJC15*SFN' 'DRAP1*GRWD1' 'DRAP1*HSPA8' 'DRAP1*PIGB'
#  'DRAP1*SNX7' 'DRAP1*TMCO1' 'DUSP6*HPRT1' 'DYNLT3*GNA11' 'EDN1*TCTA'
#  'EED*MAT2A' 'EED*OXSR1' 'FBXL12*LRRC16A' 'FBXO21*STXBP2' 'FOSL1*REEP5'
#  'GNA15*TCEAL4' 'GTPBP8*TGFB3' 'HAT1*KIAA0907' 'HEATR1*STXBP2'
#  'HMGA2*TCFL5' 'HMGCS1*RFX5' 'HMGCS1*SORBS3' 'HNRNPA2B1*SORBS3'
#  'INPP4B*NOP16' 'KLHL21*NPRL2' 'MALT1*SCP2' 'MAST2*PRKX' 'MKNK1*PMPCB'
#  'MMP2*TIMELESS' 'NCOA3*SFN' 'NENF*SNX6' 'NFE2L2*TGFB3' 'NISCH*NNT'
#  'NR1H2*NT5DC2' 'NRIP1*PGRMC1' 'NUDT9*SFN' 'P4HTM*TIMP2' 'PLA2G4A*WDTC1'
#  'PNP*TCFL5' 'PNP*USP14' 'RGS2*TIMELESS' 'SFN*SNX7' 'SQRDL*TCEAL4'
#  'SRP14*USP14' 'TES*TXNDC9' 'TOMM70A*TSPAN3' 'UQCR10*ZW10']
# ['ABL1*G3BP1' 'ADAM10*ADNP2' 'ADAM10*CASC3' 'ADAM10*KIAA0355'
#  'ADAM10*MYCBP2' 'ADAM10*SPEN' 'ADAM10*TIAM1' 'ADAM10*ZNF318' 'ADNP2*DCTD'
#  'AKR1A1*BECN1' 'AKR1A1*COPZ1' 'AKR1A1*DNAJC15' 'AKR1A1*G3BP1'
#  'AKR1A1*KCTD5' 'AKR1A1*LIPA' 'AKR1A1*PLK1' 'AKR1A1*POP4' 'AKR1A1*RPA3'
#  'AKR1A1*RPN2' 'AKR1A1*SCP2' 'AKR1A1*SDHB' 'AKR1A1*SNX17' 'AKR1A1*THAP11'
#  'AKR1A1*XPNPEP1' 'AKT1*BAG6' 'AKT1*DDX42' 'AKT1*FBXO21' 'AKT1*GNA11'
#  'AKT1*NR1H2' 'AKT1*UBE2J1' 'AKT1*USP22' 'ANKRD10*DNAJC15' 'ANO10*UBE2J1'
#  'ARHGEF12*CAB39' 'ARID4B*TM9SF2' 'ARPP19*PUM2' 'ASCC3*KIAA0355'
#  'ASCC3*TIMELESS' 'ATF6*PUM2' 'ATF6*WDTC1' 'ATG3*RUVBL1' 'ATMIN*SCRN1'
#  'AURKA*BRCA1' 'AURKA*CENPO' 'AURKA*DCK' 'AURKA*GPATCH8' 'AURKA*IKBKB'
#  'AURKA*KAT6A' 'BAG6*BCL7B' 'BAG6*G3BP1' 'BAG6*GADD45A' 'BAG6*ITFG1'
#  'BAG6*SNX7' 'BAG6*TMEM5' 'BCL7B*NR1H2' 'BECN1*PUM2' 'BECN1*UBE2J1'
#  'BECN1*WIPF2' 'BID*CENPO' 'BIRC5*CDK2' 'BIRC5*CENPO' 'BIRC5*MCM3'
#  'BIRC5*NCAPD2' 'BIRC5*NR1H2' 'BIRC5*ORC1' 'BIRC5*RFC5' 'BIRC5*TIMELESS'
#  'BIRC5*USP22' 'BRCA1*NMT1' 'BRCA1*SMARCD2' 'BUB1B*CCNB2' 'CAB39*IKBKB'
#  'CAB39*MACF1' 'CAB39*MYCBP2' 'CANT1*KIAA0355' 'CASP3*CXCR4' 'CCNA2*ORC1'
#  'CCNA2*TIMELESS' 'CCNB1*CDK1' 'CCNB1*KIF2C' 'CCNB1*LIG1' 'CCNB1*NR1H2'
#  'CCNB1*ORC1' 'CCNB1*RFC5' 'CCNB1*SUV39H1' 'CCNB2*CXCR4' 'CCNB2*RFC5'
#  'CCNB2*TIMELESS' 'CCND3*GNA11' 'CCND3*HERPUD1' 'CCND3*NOTCH1'
#  'CCND3*UBE2J1' 'CCND3*USP22' 'CCNE2*DSG2' 'CCNE2*G3BP1' 'CCNE2*IQGAP1'
#  'CCT7*MEST' 'CDC20*KIF2C' 'CDC20*LIG1' 'CDC20*NCAPD2' 'CDC20*POLE2'
#  'CDK1*UBE2C' 'CDK19*MAPK9' 'CDK19*PCMT1' 'CDK7*KIAA0907' 'CDKN2A*IQGAP1'
#  'CDKN2A*ITFG1' 'CDKN2A*PMAIP1' 'CDKN2A*PSMD10' 'CDKN2A*STAMBP'
#  'CENPO*PLK1' 'CEP57*DNAJC15' 'CEP57*MTFR1' 'CEP57*RPS6' 'CEP57*SNX17'
#  'CEP57*SNX6' 'CFLAR*DHX29' 'CGRRF1*P4HTM' 'CHAC1*SUV39H1' 'CHEK1*SMNDC1'
#  'CHEK1*TMEM5' 'CHEK2*HPRT1' 'COG2*DCTD' 'COPZ1*NR1H2' 'COPZ1*P4HTM'
#  'CSK*PIGB' 'DENND2D*DNAJC15' 'DENND2D*MELK' 'DFFA*KIAA0355'
#  'DNAJC15*MAN2B1' 'DNAJC15*MCOLN1' 'DNAJC15*MTF2' 'DNAJC15*PUM2'
#  'DNAJC15*TXLNA' 'DNAJC15*ZNF274' 'DNMT1*PLCB3' 'DSG2*LRRC16A' 'DSG2*PCM1'
#  'DSG2*TP53BP2' 'DUSP11*EPN2' 'ECD*ZNF318' 'EDEM1*EGFR' 'EDEM1*NCOA3'
#  'EDN1*GOLT1B' 'EED*TMCO1' 'EPHB2*MYCBP2' 'EXT1*GNA11' 'FAT1*RFC5'
#  'FBXL12*TIMM9' 'FBXL12*USP14' 'FBXO21*PTPRK' 'FBXO7*STXBP2' 'FYN*SNX7'
#  'G3BP1*HDAC6' 'G3BP1*IKBKE' 'G3BP1*MCM3' 'G3BP1*SMC1A' 'G3BP1*TIMELESS'
#  'GADD45A*PUM2' 'GPATCH8*NCOA3' 'HERPUD1*MAPK9' 'HERPUD1*SLC35B1'
#  'HERPUD1*TXNDC9' 'HMGCS1*TFDP1' 'HNRNPA2B1*IKBKB' 'HOOK2*TMCO1'
#  'HOOK2*USP14' 'HPRT1*MTF2' 'HSPD1*MEST' 'IGF1R*ZMYM2' 'IGF2R*KIAA0355'
#  'IKBKB*ITGB1BP1' 'IKBKB*LSR' 'IKBKB*MAPKAPK3' 'IKBKB*MRPL19'
#  'IKBKB*NCOA3' 'IKBKB*PAK4' 'IKBKB*PHKB' 'IKBKB*PTPN1' 'IKBKB*RPN2'
#  'IKBKB*STAMBP' 'IKBKB*SYPL1' 'IKBKB*TMCO1' 'IKBKB*TOR1A' 'IKBKE*ME2'
#  'IKBKE*TFDP1' 'IQGAP1*MTF2' 'KAT6A*LIPA' 'KIAA0355*SCRN1'
#  'KIAA0355*SLC5A6' 'KIF20A*LIG1' 'KIF20A*MCM3' 'KLHDC2*MNAT1'
#  'KLHDC2*MRPL12' 'KLHDC2*TCEAL4' 'KLHL21*USP14' 'LIG1*LSR' 'LIG1*RRP1B'
#  'LYPLA1*NUDT9' 'LYPLA1*ZW10' 'MACF1*MAP4K4' 'MAP2K5*RPA3' 'MAP2K5*SDHB'
#  'MAPK9*SYK' 'MAPKAPK3*P4HTM' 'MMP2*TGFB3' 'MOK*TCEAL4' 'MYCBP2*NCOA3'
#  'MYCBP2*RASA1' 'MYLK*PSMB1' 'NCK1*SKP1' 'NCOA3*PCNA' 'NCOA3*POLE2'
#  'NCOA3*PUM2' 'NFATC3*USP14' 'NGRN*NR1H2' 'NGRN*PRKX' 'NMT1*TIMELESS'
#  'NOLC1*NR1H2' 'NOSIP*NR1H2' 'NR1H2*PAK4' 'NR1H2*PCBD1' 'NR1H2*PRKAG2'
#  'NR1H2*RHEB' 'NR1H2*SLC35B1' 'NR1H2*SMAD3' 'NR1H2*SMNDC1' 'NR1H2*SNX7'
#  'NR1H2*TBPL1' 'NR1H2*UBE2C' 'NUDT9*PRKX' 'ORC1*UBE2C' 'PCNA*PLK1'
#  'PGRMC1*RBM34' 'PIGB*PUM2' 'PLCB3*TIMELESS' 'PLK1*SUV39H1'
#  'PLK1*TIMELESS' 'PLSCR1*PSME2' 'POLE2*UBE2C' 'PRKX*TMED10' 'PRKX*TMEM5'
#  'PSIP1*PXMP2' 'PSMB1*TARBP1' 'PTGS2*TCEAL4' 'PTPRK*TIMELESS'
#  'PUM2*SLC25A46' 'PUM2*SMARCD2' 'PUM2*SMNDC1' 'PUM2*STAMBP' 'PUM2*TM9SF2'
#  'PUM2*TSPAN3' 'RB1*UBE2J1' 'RFC2*TIMELESS' 'RFC5*TOP2A' 'RFC5*TSPAN6'
#  'RFC5*ZNHIT3' 'RPA3*TIMELESS' 'RRP1B*TIMELESS' 'SDHB*STXBP2' 'SDHB*WRB'
#  'SOX4*TMED10' 'STAMBP*ZFX' 'STXBP2*TMEM5' 'TCEAL4*ZNF274' 'TCTA*TMCO1'
#  'TIMELESS*UBE2C' 'TIMELESS*YME1L1' 'TIMP2*TPM1' 'TOMM70A*UBE2J1']
# ['ABCF3*HMGN1' 'ADH5*NFKBIA' 'ADI1*BAD' 'ADI1*CCND3' 'ADI1*THAP11'
#  'ADRB2*CCDC85B' 'ADRB2*ISOC1' 'AKR1A1*ATF6' 'AKR1A1*BAD' 'APPBP2*RPP38'
#  'ATF6*CETN3' 'ATP11B*MYBL2' 'ATP1B1*NUSAP1' 'ATP1B1*SDHB'
#  'ATP1B1*SLC35A1' 'ATP1B1*TBP' 'BAD*HDAC2' 'BAG6*RPL39L' 'BCL7B*PARP2'
#  'BECN1*PARP2' 'BECN1*PHKG2' 'BECN1*RFC2' 'BECN1*SUCLG1' 'BID*DDR1'
#  'BID*PRKAG2' 'BRCA1*HES1' 'BUB1B*HES1' 'BUB1B*ST6GALNAC2'
#  'CAPN1*ST6GALNAC2' 'CASP3*LGALS8' 'CASP3*SMAD3' 'CASP3*ST6GALNAC2'
#  'CASP7*PARP2' 'CCDC85B*IL4R' 'CCNA2*RPP38' 'CCNB2*KCTD5' 'CCNB2*NFKBIA'
#  'CCNB2*NUP85' 'CCNF*HES1' 'CCNF*ST6GALNAC2' 'CCP110*IFNAR1' 'CD58*DLD'
#  'CD58*SMNDC1' 'CD58*SYPL1' 'CDK2*CETN3' 'CDK2*DDR1' 'CDK2*HES1'
#  'CDK2*HIST1H2BK' 'CDK2*ISOC1' 'CDK2*KCTD5' 'CDK2*KIAA0907' 'CDK2*PARP2'
#  'CDK2*PHKG2' 'CDK2*PRPF4' 'CDK2*RFC2' 'CDK2*ST6GALNAC2' 'CDK2*XPNPEP1'
#  'CDK4*KCTD5' 'CENPO*PARP2' 'CEP57*COG7' 'CEP57*ECD' 'CEP57*HMGN1'
#  'CEP57*STAMBP' 'CETN3*HNRNPA2B1' 'CETN3*NVL' 'CETN3*PARP2' 'CETN3*POLE2'
#  'CETN3*YME1L1' 'COG2*PRKAG2' 'COG4*HERPUD1' 'COG7*HMGN1' 'COG7*TLK2'
#  'CRYZ*WDR61' 'CXCR4*PARP2' 'DAXX*RFC2' 'DAXX*RPL39L' 'DCUN1D4*DNTTIP2'
#  'DDR1*ENOPH1' 'DDR1*PCNA' 'DDX42*MTX2' 'DDX42*NFKBIA' 'DLD*PARP2'
#  'DNAJA3*PARP2' 'DNM1L*PAK6' 'DNTTIP2*PARP2' 'DNTTIP2*PPP2R3C'
#  'DUSP11*MTX2' 'EBP*ISOC1' 'ECD*MTX2' 'ECH1*SLC35A1' 'ENOPH1*RPP38'
#  'ENOSF1*LGALS8' 'FBXO7*PRKAG2' 'FBXO7*ST6GALNAC2' 'FKBP4*GMNN'
#  'FKBP4*HMGN1' 'FKBP4*SLC25A4' 'GAA*PARP2' 'GLOD4*NUP85' 'GMNN*NFKBIB'
#  'GMNN*NUP85' 'GMNN*PLS1' 'GMNN*SMC4' 'GMNN*TFDP1' 'GMNN*THAP11'
#  'GMNN*TRAP1' 'GTPBP8*HNRNPA2B1' 'HAT1*PRKAG2' 'HAT1*RNPS1' 'HAT1*SYF2'
#  'HAT1*SYPL1' 'HAX1*NFKB2' 'HDAC2*PHKG2' 'HDAC2*RFC2' 'HDAC2*THAP11'
#  'HES1*NUP85' 'HES1*ORC1' 'HES1*STMN1' 'HIST1H2BK*OXSR1' 'HMGN1*HNRNPA2B1'
#  'HMGN1*LGALS8' 'HMGN1*NFKB2' 'HMGN1*NFKBIB' 'HMGN1*PLS1' 'HMGN1*PRKAG2'
#  'HMGN1*PRKX' 'HMGN1*RPIA' 'HMGN1*RPP38' 'HMGN1*VPS72' 'HMGN1*ZNF131'
#  'HNRNPA2B1*PARP2' 'HNRNPA2B1*PMPCB' 'HNRNPA2B1*POP4' 'HNRNPA2B1*RFC2'
#  'HNRNPA2B1*TLK2' 'HNRNPA2B1*TRAPPC6A' 'ICMT*KIAA0907' 'IKBKE*TBPL1'
#  'ISOC1*PARP2' 'KCTD5*MRPS2' 'KIAA0907*KIF20A' 'KIAA0907*NUSAP1'
#  'KIAA0907*RFC2' 'KIAA0907*RNPS1' 'KIAA0907*SMC4' 'KIAA0907*XPNPEP1'
#  'KTN1*MTX2' 'LGALS8*MTF2' 'LGALS8*RFC2' 'LGALS8*SRSF4' 'LGALS8*STMN1'
#  'LGALS8*SYF2' 'LGALS8*ZDHHC6' 'LYPLA1*RNF167' 'MCM3*PARP2' 'MCM3*PRKAG2'
#  'MCM3*TBP' 'MNAT1*MTX2' 'MSH6*ZDHHC6' 'MTF2*ZNF131' 'MTX2*NUP85'
#  'MTX2*PSMD2' 'MTX2*SMC3' 'MTX2*SMNDC1' 'MTX2*SYPL1' 'NCAPD2*PARP2'
#  'NFKB2*PCBD1' 'NFKB2*UXT' 'NFKBIA*RFC2' 'NFKBIA*SDHB' 'NFKBIE*PCBD1'
#  'NIPSNAP1*PRKAG2' 'NOL3*PRKACA' 'NOTCH1*PRUNE' 'NUDT9*TOMM70A'
#  'NUP85*PARP2' 'NUP85*PSRC1' 'NUP85*RFC2' 'NUP85*TFDP1' 'NVL*PRKAG2'
#  'PARP2*RFC2' 'PARP2*RFC5' 'PARP2*SYPL1' 'PARP2*TFDP1' 'PARP2*TMCO6'
#  'PARP2*TMEM5' 'PARP2*TP53' 'PCM1*TP53' 'PHKB*YTHDF1' 'PHKG2*STMN1'
#  'PLS1*PSRC1' 'PLS1*RFC5' 'POLE2*SMC4' 'POLE2*TBP' 'PRKAG2*PRUNE'
#  'PRKAG2*SMC4' 'PRKAG2*SUZ12' 'PSMD2*RBM34' 'PSMD2*RPP38' 'PSMD2*TSPAN3'
#  'RFC2*RPP38' 'RFC2*TBP' 'RPP38*SLC35B1' 'RPP38*STMN1' 'RPP38*TLK2'
#  'RPP38*TMEM97' 'RPP38*UBE2A' 'SLC25A4*SMARCD2' 'ST6GALNAC2*TBP'
#  'VPS72*XPNPEP1']

# %%
d = pd.read_csv("../data/permutation_test_results.csv", sep=";")
d
# Out:
#    project interaction-type  n-hits  \
# 0     STAD         additive     114
# 1     STAD        competing     118
# 2     STAD              xor      42
# 3     READ         additive     331
# 4     READ        competing     494
# ..     ...              ...     ...
# 58    CESC        competing     142
# 59    CESC              xor      44
# 60    BRCA         additive     124
# 61    BRCA        competing     196
# 62    BRCA              xor      55
#
#                                                  hits
# 0   [ABHD4*PARP1,ABHD4*TMEM97,ACBD3*DPH2,ACD*SPDEF...
# 1   [ABCC5*SPDEF,ABCC5*XPNPEP1,ACD*TRAPPC3,ADAM10*...
# 2   [ARFIP2*CALM3,BDH1*GRWD1,BUB1B*TMEM97,CALM3*HN...
# 3   [AARS*FIS1,AARS*LOXL1,ABHD6*FIS1,ADCK3*ATP6V1F...
# 4   [AARS*BRPF1,AARS*CAMSAP2,AARS*DDX42,AARS*HMGCS...
# ..                                                ...
# 58  [ABL1*DNMT1,ABL1*OXCT1,ABL1*PIK3R4,ADNP2*DDB2,...
# 59  [ACD*SATB1,ACD*UBE3B,ARHGEF12*BLMH,ATMIN*PROS1...
# 60  [ABCC5*CDKN2A,ABCC5*NOP16,ABCC5*TCERG1,ABL1*IC...
# 61  [AARS*BMP4,ABCC5*ASAH1,ABCC5*CGRRF1,ABCC5*SPDE...
# 62  [ABCC5*RBKS,ACAA1*PRKACA,ACLY*RAE1,ADAT1*LYN,A...
#
# [63 rows x 4 columns]

# %%
end = "\\"
for pr in np.unique(d["project"].values):
    df = d[d['project'] == pr]
    add = df[df['interaction-type'] == 'additive']['n-hits'].values[0]
    com = df[df['interaction-type'] == 'competing']['n-hits'].values[0]
    xor = df[df['interaction-type'] == 'xor']['n-hits'].values[0]
    print(f"{pr} & {add} & {com} & {xor} {end}{end}")
# Out:
# BLCA & 113 & 149 & 58 \\
# BRCA & 124 & 196 & 55 \\
# CESC & 91 & 142 & 44 \\
# COAD & 89 & 51 & 22 \\
# GBM & 95 & 97 & 37 \\
# HNSC & 112 & 272 & 217 \\
# KIRC & 527 & 571 & 16 \\
# KIRP & 68 & 95 & 25 \\
# LAML & 277 & 339 & 45 \\
# LGG & 253 & 382 & 26 \\
# LIHC & 106 & 115 & 18 \\
# LUAD & 113 & 137 & 38 \\
# LUSC & 73 & 64 & 23 \\
# METABRIC & 830 & 925 & 17 \\
# OV & 83 & 105 & 69 \\
# PRAD & 54 & 27 & 59 \\
# READ & 331 & 494 & 305 \\
# SKCM & 138 & 122 & 59 \\
# STAD & 114 & 118 & 42 \\
# THCA & 101 & 116 & 63 \\
# UCEC & 105 & 129 & 31 \\
